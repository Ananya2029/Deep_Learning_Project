# %%
text =" This is a Sample for Tokenization demo"

# %%
word_tokens=text.split()
print("Word Tokens:",word_tokens)
# Out:
# Word Tokens: ['This', 'is', 'a', 'Sample', 'for', 'Tokenization', 'demo']

# %%
char_tokens=list(text)
print("Character Tokens",char_tokens)
# Out:
# Character Tokens [' ', 'T', 'h', 'i', 's', ' ', 'i', 's', ' ', 'a', ' ', 'S', 'a', 'm', 'p', 'l', 'e', ' ', 'f', 'o', 'r', ' ', 'T', 'o', 'k', 'e', 'n', 'i', 'z', 'a', 't', 'i', 'o', 'n', ' ', 'd', 'e', 'm', 'o']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentence="Hello world"

# %%
normalized_text = "".join([char for char in normalized_text if char.isalnum() or char.isspace()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1027/809766074.py in <cell line: 0>()
# ----> 1 normalized_text = "".join([char for char in normalized_text if char.isalnum() or char.isspace()])
#
# NameError: name 'normalized_text' is not defined

# %%
normalized_text="".join(normalized_text.split())
print("Original text",text)
print("Normalized Text :",normalized_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1027/2804249090.py in <cell line: 0>()
# ----> 1 normalized_text="".join(normalized_text.split())
#       2 print("Original text",text)
#       3 print("Normalized Text :",normalized_text)
#
# NameError: name 'normalized_text' is not defined

# %% [markdown]
# Stop word

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import re
text =  input("Enter the text:")
words=re.sub(r'[^\w\s]',"",text).split()
filterd_words=[words for qord in words if word not in stop_words]

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
text="tHE CATS WERE RUNNING AND STUDING"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# stemming
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word)for word in text.split()]
print(stemmed_words)
# Out:
# ['the', 'cat', 'were', 'run', 'and', 'stude']

# %%
# lemmatization
lemmatizer= WordNetLemmatizer()
lemmatized_word=[lemmatizer.lemmatize(word)for word in text.split()]
print(lemmatized_word)
# Out:
# ['tHE', 'CATS', 'WERE', 'RUNNING', 'AND', 'STUDING']
